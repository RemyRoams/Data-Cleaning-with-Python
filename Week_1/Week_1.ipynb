# %%
import pandas as pd

# %%
# Importing data
df = pd.read_csv('PD_2024_Wk_1_Input.csv')
df.head()
# Out:
#                                       Flight Details  Flow Card?  \
# 0   2024-07-22//PA010//Tokyo-New York//Economy//2380           1
# 1   2024-09-28//PA008//Perth-New York//Economy//1855           0
# 2  2024-04-20//PA002//New York-London//Economy//3490           1
# 3  2024-01-23//PA010//Tokyo-New York//Premium Eco...           1
# 4  2024-10-01//PA008//Perth-New York//Business Cl...           0
#
#    Bags Checked   Meal Type
# 0             0    Egg Free
# 1             2  Vegetarian
# 2             1       Vegan
# 3             1  Vegetarian
# 4             0  Vegetarian

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3778 entries, 0 to 3777
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flight Details  3778 non-null   object
#  1   Flow Card?      3778 non-null   int64
#  2   Bags Checked    3778 non-null   int64
#  3   Meal Type       3189 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 118.2+ KB

# %%
df.describe()
# Out:
#         Flow Card?  Bags Checked
# count  3778.000000   3778.000000
# mean      0.498412      1.507941
# std       0.500064      1.121228
# min       0.000000      0.000000
# 25%       0.000000      1.000000
# 50%       0.000000      2.000000
# 75%       1.000000      3.000000
# max       1.000000      3.000000

# %%
# Creating list for extracting the data
t_date = []
t_flight_number = []
t_route_from = []
t_route_to = []
t_class_type = []
t_price = []

# %%
# For Loop to iterate each element on the Flight Details Column
for flight in df["Flight Details"]:
    # Extracting data from the string
    date, flight_number, route, class_type, price = flight.split("//")

    # Extracting Origin and Destination
    route_from, route_to = route.split("-")

    # Tidying-up the Date
    date = date.replace('-', '/')
    date = "/".join(date.split("/")[::-1])
        # .split("/") → Converts "2024/07/22" into ['2024', '07', '22']
        # [::-1] → Reverses the list to ['22', '07', '2024']
        # "/".join(...) → Joins it back into "22/07/2024"

    # Rounding the price
    price = float(price)
    price = round(price, 2)

    # Inserting data extracted into lists
    t_date.append(date)
    t_flight_number.append(flight_number)
    t_route_from.append(route_from)
    t_route_to.append(route_to)
    t_class_type.append(class_type)
    t_price.append(price)

# %%
# Converting lists into df columns
df["Date"] = t_date
df["Flight Number"] = t_flight_number
df["From"] = t_route_from
df["To"] = t_route_to
df["Class"] = t_class_type
df["Price"] = t_price

df.head()
# Out:
#                                       Flight Details  Flow Card?  \
# 0   2024-07-22//PA010//Tokyo-New York//Economy//2380           1
# 1   2024-09-28//PA008//Perth-New York//Economy//1855           0
# 2  2024-04-20//PA002//New York-London//Economy//3490           1
# 3  2024-01-23//PA010//Tokyo-New York//Premium Eco...           1
# 4  2024-10-01//PA008//Perth-New York//Business Cl...           0
#
#    Bags Checked   Meal Type        Date Flight Number      From        To  \
# 0             0    Egg Free  22/07/2024         PA010     Tokyo  New York
# 1             2  Vegetarian  28/09/2024         PA008     Perth  New York
# 2             1       Vegan  20/04/2024         PA002  New York    London
# 3             1  Vegetarian  23/01/2024         PA010     Tokyo  New York
# 4             0  Vegetarian  01/10/2024         PA008     Perth  New York
#
#              Class   Price
# 0          Economy  2380.0
# 1          Economy  1855.0
# 2          Economy  3490.0
# 3  Premium Economy   825.0
# 4   Business Class   634.8

# %%
# Rearranging and dropping unwanted columns
df = df[['Date', 'Flight Number', 'From', 'To', 'Class', 'Price', 'Flow Card?', 'Bags Checked', 'Meal Type']]

# %%
# Preview of Output Data
df
# Out:
#             Date Flight Number      From        To            Class   Price  \
# 0     22/07/2024         PA010     Tokyo  New York          Economy  2380.0
# 1     28/09/2024         PA008     Perth  New York          Economy  1855.0
# 2     20/04/2024         PA002  New York    London          Economy  3490.0
# 3     23/01/2024         PA010     Tokyo  New York  Premium Economy   825.0
# 4     01/10/2024         PA008     Perth  New York   Business Class   634.8
# ...          ...           ...       ...       ...              ...     ...
# 3773  05/05/2024         PA009  New York     Tokyo          Economy  1360.0
# 3774  14/06/2024         PA008     Perth  New York      First Class   245.0
# 3775  16/01/2024         PA010     Tokyo  New York          Economy  2410.0
# 3776  16/08/2024         PA005    London     Tokyo  Premium Economy   960.0
# 3777  06/01/2024         PA004     Perth    London      First Class   236.0
#
#       Flow Card?  Bags Checked   Meal Type
# 0              1             0    Egg Free
# 1              0             2  Vegetarian
# 2              1             1       Vegan
# 3              1             1  Vegetarian
# 4              0             0  Vegetarian
# ...          ...           ...         ...
# 3773           0             3    Nut Free
# 3774           0             1  Dairy Free
# 3775           0             2    Egg Free
# 3776           0             0    Nut Free
# 3777           1             1    Nut Free
#
# [3778 rows x 9 columns]

# %%
# Changing 1/0 to Yes/No
df['Flow Card?'] = df['Flow Card?'].replace({1: "Yes", 0: "No"})
df.head()
# Out:
#          Date Flight Number      From        To            Class   Price  \
# 0  22/07/2024         PA010     Tokyo  New York          Economy  2380.0
# 1  28/09/2024         PA008     Perth  New York          Economy  1855.0
# 2  20/04/2024         PA002  New York    London          Economy  3490.0
# 3  23/01/2024         PA010     Tokyo  New York  Premium Economy   825.0
# 4  01/10/2024         PA008     Perth  New York   Business Class   634.8
#
#   Flow Card?  Bags Checked   Meal Type
# 0        Yes             0    Egg Free
# 1         No             2  Vegetarian
# 2        Yes             1       Vegan
# 3        Yes             1  Vegetarian
# 4         No             0  Vegetarian

# %%
# Creating each table
df_flowcard_yes = df[df["Flow Card?"] == "Yes"]
df_flowcard_yes
# Out:
#             Date Flight Number      From        To            Class   Price  \
# 0     22/07/2024         PA010     Tokyo  New York          Economy  2380.0
# 2     20/04/2024         PA002  New York    London          Economy  3490.0
# 3     23/01/2024         PA010     Tokyo  New York  Premium Economy   825.0
# 6     05/06/2024         PA006     Tokyo    London      First Class   618.0
# 8     30/03/2024         PA004     Perth    London      First Class   446.0
# ...          ...           ...       ...       ...              ...     ...
# 3764  23/11/2024         PA005    London     Tokyo          Economy  2070.0
# 3766  04/11/2024         PA003    London     Perth      First Class   210.0
# 3770  29/04/2024         PA012     Tokyo     Perth          Economy  3490.0
# 3772  26/09/2024         PA001    London  New York      First Class   207.0
# 3777  06/01/2024         PA004     Perth    London      First Class   236.0
#
#      Flow Card?  Bags Checked   Meal Type
# 0           Yes             0    Egg Free
# 2           Yes             1       Vegan
# 3           Yes             1  Vegetarian
# 6           Yes             3       Vegan
# 8           Yes             1    Nut Free
# ...         ...           ...         ...
# 3764        Yes             2    Egg Free
# 3766        Yes             3    Nut Free
# 3770        Yes             0  Dairy Free
# 3772        Yes             2  Vegetarian
# 3777        Yes             1    Nut Free
#
# [1883 rows x 9 columns]

# %%
# Creating each table
df_flowcard_no = df[df["Flow Card?"] == "No"]
df_flowcard_no
# Out:
#             Date Flight Number      From        To            Class   Price  \
# 1     28/09/2024         PA008     Perth  New York          Economy  1855.0
# 4     01/10/2024         PA008     Perth  New York   Business Class   634.8
# 5     04/03/2024         PA007  New York     Perth   Business Class   458.4
# 7     25/02/2024         PA010     Tokyo  New York  Premium Economy  1435.0
# 13    29/03/2024         PA004     Perth    London          Economy  2730.0
# ...          ...           ...       ...       ...              ...     ...
# 3771  06/03/2024         PA006     Tokyo    London  Premium Economy   940.0
# 3773  05/05/2024         PA009  New York     Tokyo          Economy  1360.0
# 3774  14/06/2024         PA008     Perth  New York      First Class   245.0
# 3775  16/01/2024         PA010     Tokyo  New York          Economy  2410.0
# 3776  16/08/2024         PA005    London     Tokyo  Premium Economy   960.0
#
#      Flow Card?  Bags Checked   Meal Type
# 1            No             2  Vegetarian
# 4            No             0  Vegetarian
# 5            No             3    Nut Free
# 7            No             0         NaN
# 13           No             2       Vegan
# ...         ...           ...         ...
# 3771         No             2  Vegetarian
# 3773         No             3    Nut Free
# 3774         No             1  Dairy Free
# 3775         No             2    Egg Free
# 3776         No             0    Nut Free
#
# [1895 rows x 9 columns]

# %%
# Exporting data
df_flowcard_yes.to_csv('Week_1.1_Data_Cleaning.csv', index=False)

# %%
# Exporting data
df_flowcard_no.to_csv('Week_1.2_Data_Cleaning.csv', index=False)
